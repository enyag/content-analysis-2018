# %%
import lucem_illud #pip install git+git://github.com/Computational-Content-Analysis-2018/lucem_illud.git

import requests #for http requests
import nltk #the Natural Language Toolkit
import pandas #gives us DataFrames
import matplotlib.pyplot as plt #For graphics
import wordcloud #Makes word clouds
import numpy as np #For divergences/distances
import scipy #For divergences/distances
import seaborn as sns #makes our plots look nicer
import sklearn.manifold #For a manifold plot
from nltk.corpus import stopwords #For stopwords
import json #For API responses
import urllib.parse #For joining urls

import bs4
import re

# %matplotlib inline

# %% [markdown]
# ANALYSIS FOR SPEECH MAY 25, 2016

# %%
DOS052516_url = 'https://2009-2017.state.gov/s/cyberissues/releasesandremarks/257719.htm'
DOS052516_save = 'DOS052516_url.html'
DOS052516 = requests.get(DOS052516_url)
DOS052516Soup = bs4.BeautifulSoup(DOS052516.text, 'html.parser')
with open(DOS052516_save, mode='w', encoding='utf-8') as f:
    f.write(DOS052516.text)
DOS052516PTags = DOS052516Soup.body.findAll('p')
DOS052516P = []
for pTag in DOS052516PTags:
    DOS052516P.append(pTag.text)

with open('DOS052516.txt', encoding = 'utf-8') as f:
    DOS052516 = f.read()

DOS052516Tokens = nltk.word_tokenize(DOS052516)

DOS052516Text = nltk.Text(DOS052516Tokens)

DOS052516Index = nltk.text.ConcordanceIndex(DOS052516Text)
DOS052516Index.print_concordance('cyber')
# Out:
# Displaying 25 of 62 matches:
#  update on key developments in our cyber foreign policy efforts.\ Since I t
#  broad international framework for cyber stability , as well some of the al
# eats posed by continuing malicious cyber activity directed at the United St
# rategic framework of international cyber stability designed to achieve and
# of our framework for international cyber stability is the applicability of
# ropose a set of specific peacetime cyber norms , including the cybersecurit
# e requests in mitigating malicious cyber activity emanating from their terr
#  work on law and voluntary norms , cyber CBMs have the potential to contrib
# ute substantially to international cyber stability . CBMs have been used fo
# nternational concern . Examples of cyber CBMs include : transparency measur
#  initiative to combat a particular cyber incident or threat actor ; and sta
#  it is important to recognize that cyber issues are new to many states , an
# ive views on how we should promote cyber stability . Notwithstanding these
# rategic framework of international cyber stability . At this point , I woul
# States strongly opposes the use of cyber technology to steal intellectual p
# 2015 on several key commitments on cyber issues . These commitments are : \
# and assistance regarding malicious cyber activity emanating from their terr
# on international law and voluntary cyber norms of state behavior . We also
# e all our challenges with China on cyber issues . However , they do represe
# championed vision of international cyber stability and its pillars.\ Among
# uld reach out to in the event of a cyber incident emanating from the state\
# ctor , requires the integration of cyber , physical , and human elements .
# of and immediately following major cyber conferences , such as the Global C
# mbat what it argues is an emerging cyber arms race and \'91militarization\'
# China has been willing to consider cyber confidence building measures , and

# %%
DOS052516PD = pandas.DataFrame({'paragraph-text' : DOS052516P})
print (DOS052516PD)
# Out:
#                                        paragraph-text
# 0                                    You are viewing:
# 1   Information released online from January 20, 2...
# 2
# 3   Chairman Gardner, Ranking Member Cardin, membe...
# 4   Since I testified before your Subcommittee one...
# 5   It is also important to note that last month, ...
# 6   As reflected in the Strategy we provided to Co...
# 7   I am happy to answer any questions regarding t...
# 8   In spite of the successes outlined in the Stra...
# 9   Diplomatic Efforts to Shape the Policy Environ...
# 10  Building a Framework for International Stabili...
# 11  The Department of State, working with our inte...
# 12  This framework has three key elements: (1) glo...
# 13  Since 2009, the United Nations Group of Govern...
# 14  Applicability of international law. The first ...
# 15  Norms of responsible state behavior. The Unite...
# 16  Confidence Building Measures. Together with ou...
# 17  Although many of the elements of the framework...
# 18                       U.S.-China Cyber Commitments
# 19  The United States strongly opposes the use of ...
# 20  (1) both governments agreed to cooperate and p...
# 21  (2) neither country’s government will conduct ...
# 22  (3) both governments will work together to fur...
# 23  (4) both governments will establish a Minister...
# 24  Two weeks ago today – on May 11 – the United S...
# 25  To implement other commitments reached during ...
# 26  Moreover, regarding the commitment that neithe...
# 27  The outcomes of last year’s Xi-Obama summit fo...
# 28               Group of Twenty (G20) Antalya Summit
# 29  In November 2015, the leaders of the G20 met i...
# ..                                                ...
# 41  Russia has nonetheless found common ground wit...
# 42  We counter these alternative concepts of cyber...
# 43      Responding to and Preventing Cyber Incidents
# 44                          Continuing Cyber Threats
# 45  Cyber threats to U.S. national and economic se...
# 46  Overall, the unclassified information and comm...
# 47  In February, Director of National Intelligence...
# 48  The Intelligence Community continues to witnes...
# 49          Tools Available to Counter Cyber Threats
# 50  The United States works to counter technical c...
# 51  The United States believes that deterrence in ...
# 52  The President has at his disposal a number of ...
# 53  With respect to cost imposition, the President...
# 54  Diplomatic tools provide a way to communicate ...
# 55  Law enforcement tools can be used to investiga...
# 56  Economic tools, such as financial sanctions, m...
# 57  Military capabilities provide an important set...
# 58  Intelligence capabilities are also an importan...
# 59  Even with this broad range of tools, deterring...
# 60                                 Capacity Building
# 61  In addition to the tools that I have just outl...
# 62  In 2015, for example, the United States joined...
# 63  In another example of capacity building, the D...
# 64  The Department of State is committed to contin...
# 65                                      Looking ahead
# 66  Cybersecurity will continue to be a challenge ...
# 67  The Department will continue to spearhead the ...
# 68  The Department of State remains appreciative o...
# 69
# 70  \nThe Office of Website Management, Bureau of ...
#
# [71 rows x 1 columns]

# %%
def wordCounter(wordLst):
    wordCounts = {}
    for word in wordLst:
        wLower = word.lower()
        if wLower in wordCounts:
            wordCounts[wLower] += 1
        else:
            wordCounts[wLower] = 1
    countsForFrame = {'word' : [], 'count' : []}
    for w, c in wordCounts.items():
        countsForFrame['word'].append(w)
        countsForFrame['count'].append(c)
    return pandas.DataFrame(countsForFrame)

countedWords = wordCounter(DOS052516Text)

words = [word.lower() for word in DOS052516Text]
freq = nltk.FreqDist(words)
print (freq['cyber'])
# Out:
# 71

# %%
countedWords.sort_values('count', ascending=False, inplace=True)
countedWords[:100]
# Out:
#       count                                  word
# 25      286                                   the
# 19      254                                     ,
# 24      207                                    of
# 31      195                                   and
# 39      172                                    to
# 49      119                                    in
# 128      88                                     .
# 51       71                                 cyber
# 37       57                                     a
# 27       56                                    on
# 32       54                         international
# 119      51                                states
# 81       49                                  that
# 84       45                                    as
# 90       45                                   for
# 95       41                            cyberspace
# 118      40                                united
# 61       38                                 state
# 36       32                                    is
# 50       28                                   our
# 68       27                                  with
# 86       25                                    by
# 296      24                                   law
# 69       23                                 other
# 60       22                            department
# 4        22                                     ;
# 138      21                                   its
# 290      21                                  this
# 78       20                                  also
# 246      20                                   are
# ...     ...                                   ...
# 254      10                                    at
# 174      10                              capacity
# 177      10                                  such
# 338      10                                   set
# 145      10                             including
# 52       10                               foreign
# 66       10                                  work
# 310      10                              measures
# 325      10                                    un
# 364       9                               conduct
# 322       9                           information
# 13        9  \pard\pardeftab720\partightenfactor0
# 15        9                                  \cf0
# 187       9                            diplomatic
# 824       9                               through
# 1057      9                          capabilities
# 170       9                              internet
# 127       9                                 build
# 412       9                                   can
# 106       9                               efforts
# 354       9                                 first
# 417       9                              critical
# 400       8                                    be
# 403       8                              economic
# 401       8                              national
# 677       8                            developing
# 252       8                              activity
# 370       8                           commitments
# 153       8                             community
# 224       8                                 range
#
# [100 rows x 2 columns]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(range(len(countedWords)), countedWords['count'])
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(range(len(countedWords)), countedWords['count'])
ax.set_yscale('log')
ax.set_xscale('log')
plt.show()

# %%
print(countedWords[countedWords['word'] == 'cyberspace'])
DOS052516Index.print_concordance('cyberspace')
# Out:
#     count        word
# 95     41  cyberspace
# Displaying 25 of 35 matches:
# f responsible state behavior in cyberspace , alternative concepts for norm
# artment of State structures its cyberspace diplomacy in close cooperation
# tment actively is mainstreaming cyberspace issues into its foreign diploma
# achieve and maintain a peaceful cyberspace environment where all states ar
# aw applies to state behavior in cyberspace ; ( 2 ) development of an inter
# f responsible state behavior in cyberspace that apply during peacetime ; a
#  ) , which promote stability in cyberspace by reducing the risks of misper
# onal community on international cyberspace norms and CBMs . The UN GGE pro
# tional law to state behavior in cyberspace . The 2013 UN GGE report was a
# N Charter , to state conduct in cyberspace . The 2013 report underscored t
# rscored that states must act in cyberspace under the established internati
# f responsible state behavior in cyberspace that define key areas of risk t
# iate norms of state behavior in cyberspace and hold a senior experts group
# nternational security issues in cyberspace ; and\ ( 4 ) both governments w
# nternational security issues in cyberspace , which provided a forum to fur
# ding norms of state behavior in cyberspace and other topics . The Departme
# roach to promoting stability in cyberspace . But there is still more to do
#  and promote the same vision of cyberspace held by the United States . Non
# ge to the implementation of our cyberspace strategy is a competing and alt
# cesses.\ China\'92s approach to cyberspace in the international context is
# n sovereignty over its domestic cyberspace , and combat what it argues is
# e and \'91militarization\'92 of cyberspace . China has been willing to con
# at international law applies in cyberspace , but has not been willing to a
# irs , national sovereignty over cyberspace , and \'93no first use\'94 of w
# ernet.\ Russia\'92s approach to cyberspace in the international context ha

# %%
DOS052516Text.collocations()
# Out:
# United States; state behavior; capacity building; law enforcement;
# intellectual property; international law; responsible state; critical
# infrastructure; malicious cyber; private sector; Intelligence
# Community; cyber activity; last month; Executive Order; experts group;
# technical challenges; international cyber; cyber stability; senior
# experts; Cyberspace \i0

# %%
DOS052516Text.common_contexts(['cyber'])
# Out:
# our_foreign for_stability malicious_activity international_stability
# peacetime_norms ,_cbms of_cbms particular_incident ._cbms that_issues
# promote_stability u.s.-china_commitments of_technology
# u.s.-china_working on_issues voluntary_norms a_incident of_,
# major_conferences emerging_arms

# %%
sns.reset_orig()
DOS052516Text.dispersion_plot(['cyber', 'cyberspace','stability', 'norms','international','issues'])
sns.set()

# %%
DOS052516PD['tokenized_text'] = DOS052516PD['paragraph-text'].apply(lambda x: nltk.word_tokenize(x))

# %%
type(DOS052516PD['tokenized_text'])
# Out:
# pandas.core.series.Series

# %%
countsDict = {}
for word in DOS052516PD['tokenized_text'].sum():
    if word in countsDict:
        countsDict[word] += 1
    else:
        countsDict[word] = 1
word_counts = sorted(countsDict.items(), key = lambda x : x[1], reverse = True)
word_counts[:30]
# Out:
# [(',', 260),
#  ('the', 252),
#  ('of', 211),
#  ('and', 197),
#  ('to', 175),
#  ('.', 142),
#  ('in', 107),
#  ('cyber', 63),
#  ('a', 57),
#  ('on', 56),
#  ('that', 49),
#  ('for', 45),
#  ('as', 44),
#  ('international', 44),
#  ('United', 40),
#  ('The', 38),
#  ('States', 37),
#  ('cyberspace', 36),
#  ('is', 33),
#  ('our', 28),
#  ('with', 26),
#  ('other', 25),
#  ('by', 25),
#  ('state', 25),
#  ('Department', 23),
#  ('’', 23),
#  ('law', 22),
#  ('are', 21),
#  ('from', 21),
#  ('its', 21)]

# %%
stop_words_freq = []
for word, count in word_counts:
    if word == 'cyber':
        break
    else:
        stop_words_freq.append(word)
stop_words_freq
wordnet = nltk.stem.WordNetLemmatizer()
wordnet.lemmatize('are')
# Out:
# 'are'

# %%
print (', '.join(stopwords.words('english')))
# Out:
# i, me, my, myself, we, our, ours, ourselves, you, you're, you've, you'll, you'd, your, yours, yourself, yourselves, he, him, his, himself, she, she's, her, hers, herself, it, it's, its, itself, they, them, their, theirs, themselves, what, which, who, whom, this, that, that'll, these, those, am, is, are, was, were, be, been, being, have, has, had, having, do, does, did, doing, a, an, the, and, but, if, or, because, as, until, while, of, at, by, for, with, about, against, between, into, through, during, before, after, above, below, to, from, up, down, in, out, on, off, over, under, again, further, then, once, here, there, when, where, why, how, all, any, both, each, few, more, most, other, some, such, no, nor, not, only, own, same, so, than, too, very, s, t, can, will, just, don, don't, should, should've, now, d, ll, m, o, re, ve, y, ain, aren, aren't, couldn, couldn't, didn, didn't, doesn, doesn't, hadn, hadn't, hasn, hasn't, haven, haven't, isn, isn't, ma, mightn, mightn't, mustn, mustn't, needn, needn't, shan, shan't, shouldn, shouldn't, wasn, wasn't, weren, weren't, won, won't, wouldn, wouldn't

# %%
stop_words_nltk = stopwords.words('english')
porter = nltk.stem.porter.PorterStemmer()
snowball = nltk.stem.snowball.SnowballStemmer('english')
wordnet = nltk.stem.WordNetLemmatizer()
def normlizeTokens(tokenLst, stopwordLst = None, stemmer = None, lemmer = None):
    #We can use a generator here as we just need to iterate over it

    #Lowering the case and removing non-words
    workingIter = (w.lower() for w in tokenLst if w.isalpha())

    #Now we can use the semmer, if provided
    if stemmer is not None:
        workingIter = (stemmer.stem(w) for w in workingIter)
        
    #And the lemmer
    if lemmer is not None:
        workingIter = (lemmer.lemmatize(w) for w in workingIter)
    
    #And remove the stopwords
    if stopwordLst is not None:
        workingIter = (w for w in workingIter if w not in stopwordLst)
    #We will return a list with the stopwords removed
    return list(workingIter)

DOS052516PD['normalized_tokens'] = DOS052516PD['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = porter))
DOS052516PD['normalized_tokens_count'] = DOS052516PD['normalized_tokens'].apply(lambda x: len(x))

DOS052516PD
# Out:
#                                        paragraph-text  \
# 0                                    You are viewing:
# 1   Information released online from January 20, 2...
# 2
# 3   Chairman Gardner, Ranking Member Cardin, membe...
# 4   Since I testified before your Subcommittee one...
# 5   It is also important to note that last month, ...
# 6   As reflected in the Strategy we provided to Co...
# 7   I am happy to answer any questions regarding t...
# 8   In spite of the successes outlined in the Stra...
# 9   Diplomatic Efforts to Shape the Policy Environ...
# 10  Building a Framework for International Stabili...
# 11  The Department of State, working with our inte...
# 12  This framework has three key elements: (1) glo...
# 13  Since 2009, the United Nations Group of Govern...
# 14  Applicability of international law. The first ...
# 15  Norms of responsible state behavior. The Unite...
# 16  Confidence Building Measures. Together with ou...
# 17  Although many of the elements of the framework...
# 18                       U.S.-China Cyber Commitments
# 19  The United States strongly opposes the use of ...
# 20  (1) both governments agreed to cooperate and p...
# 21  (2) neither country’s government will conduct ...
# 22  (3) both governments will work together to fur...
# 23  (4) both governments will establish a Minister...
# 24  Two weeks ago today – on May 11 – the United S...
# 25  To implement other commitments reached during ...
# 26  Moreover, regarding the commitment that neithe...
# 27  The outcomes of last year’s Xi-Obama summit fo...
# 28               Group of Twenty (G20) Antalya Summit
# 29  In November 2015, the leaders of the G20 met i...
# ..                                                ...
# 41  Russia has nonetheless found common ground wit...
# 42  We counter these alternative concepts of cyber...
# 43      Responding to and Preventing Cyber Incidents
# 44                          Continuing Cyber Threats
# 45  Cyber threats to U.S. national and economic se...
# 46  Overall, the unclassified information and comm...
# 47  In February, Director of National Intelligence...
# 48  The Intelligence Community continues to witnes...
# 49          Tools Available to Counter Cyber Threats
# 50  The United States works to counter technical c...
# 51  The United States believes that deterrence in ...
# 52  The President has at his disposal a number of ...
# 53  With respect to cost imposition, the President...
# 54  Diplomatic tools provide a way to communicate ...
# 55  Law enforcement tools can be used to investiga...
# 56  Economic tools, such as financial sanctions, m...
# 57  Military capabilities provide an important set...
# 58  Intelligence capabilities are also an importan...
# 59  Even with this broad range of tools, deterring...
# 60                                 Capacity Building
# 61  In addition to the tools that I have just outl...
# 62  In 2015, for example, the United States joined...
# 63  In another example of capacity building, the D...
# 64  The Department of State is committed to contin...
# 65                                      Looking ahead
# 66  Cybersecurity will continue to be a challenge ...
# 67  The Department will continue to spearhead the ...
# 68  The Department of State remains appreciative o...
# 69
# 70  \nThe Office of Website Management, Bureau of ...
#
#                                        tokenized_text  \
# 0                              [You, are, viewing, :]
# 1   [Information, released, online, from, January,...
# 2                                                  []
# 3   [Chairman, Gardner, ,, Ranking, Member, Cardin...
# 4   [Since, I, testified, before, your, Subcommitt...
# 5   [It, is, also, important, to, note, that, last...
# 6   [As, reflected, in, the, Strategy, we, provide...
# 7   [I, am, happy, to, answer, any, questions, reg...
# 8   [In, spite, of, the, successes, outlined, in, ...
# 9   [Diplomatic, Efforts, to, Shape, the, Policy, ...
# 10  [Building, a, Framework, for, International, S...
# 11  [The, Department, of, State, ,, working, with,...
# 12  [This, framework, has, three, key, elements, :...
# 13  [Since, 2009, ,, the, United, Nations, Group, ...
# 14  [Applicability, of, international, law, ., The...
# 15  [Norms, of, responsible, state, behavior, ., T...
# 16  [Confidence, Building, Measures, ., Together, ...
# 17  [Although, many, of, the, elements, of, the, f...
# 18                   [U.S.-China, Cyber, Commitments]
# 19  [The, United, States, strongly, opposes, the, ...
# 20  [(, 1, ), both, governments, agreed, to, coope...
# 21  [(, 2, ), neither, country, ’, s, government, ...
# 22  [(, 3, ), both, governments, will, work, toget...
# 23  [(, 4, ), both, governments, will, establish, ...
# 24  [Two, weeks, ago, today, –, on, May, 11, –, th...
# 25  [To, implement, other, commitments, reached, d...
# 26  [Moreover, ,, regarding, the, commitment, that...
# 27  [The, outcomes, of, last, year, ’, s, Xi-Obama...
# 28    [Group, of, Twenty, (, G20, ), Antalya, Summit]
# 29  [In, November, 2015, ,, the, leaders, of, the,...
# ..                                                ...
# 41  [Russia, has, nonetheless, found, common, grou...
# 42  [We, counter, these, alternative, concepts, of...
# 43  [Responding, to, and, Preventing, Cyber, Incid...
# 44                       [Continuing, Cyber, Threats]
# 45  [Cyber, threats, to, U.S., national, and, econ...
# 46  [Overall, ,, the, unclassified, information, a...
# 47  [In, February, ,, Director, of, National, Inte...
# 48  [The, Intelligence, Community, continues, to, ...
# 49    [Tools, Available, to, Counter, Cyber, Threats]
# 50  [The, United, States, works, to, counter, tech...
# 51  [The, United, States, believes, that, deterren...
# 52  [The, President, has, at, his, disposal, a, nu...
# 53  [With, respect, to, cost, imposition, ,, the, ...
# 54  [Diplomatic, tools, provide, a, way, to, commu...
# 55  [Law, enforcement, tools, can, be, used, to, i...
# 56  [Economic, tools, ,, such, as, financial, sanc...
# 57  [Military, capabilities, provide, an, importan...
# 58  [Intelligence, capabilities, are, also, an, im...
# 59  [Even, with, this, broad, range, of, tools, ,,...
# 60                               [Capacity, Building]
# 61  [In, addition, to, the, tools, that, I, have, ...
# 62  [In, 2015, ,, for, example, ,, the, United, St...
# 63  [In, another, example, of, capacity, building,...
# 64  [The, Department, of, State, is, committed, to...
# 65                                   [Looking, ahead]
# 66  [Cybersecurity, will, continue, to, be, a, cha...
# 67  [The, Department, will, continue, to, spearhea...
# 68  [The, Department, of, State, remains, apprecia...
# 69                                                 []
# 70  [The, Office, of, Website, Management, ,, Bure...
#
#                                     normalized_tokens  normalized_tokens_count
# 0                                              [view]                        1
# 1   [inform, releas, onlin, januari, januari, note...                       24
# 2                                                  []                        0
# 3   [chairman, gardner, rank, member, cardin, memb...                       25
# 4   [sinc, testifi, befor, subcommitte, one, year,...                       23
# 5   [also, import, note, last, month, requir, cons...                       69
# 6   [reflect, strategi, provid, congress, last, mo...                       75
# 7   [happi, answer, ani, question, regard, strateg...                       24
# 8   [spite, success, outlin, strategi, vision, ope...                       65
# 9          [diplomat, effort, shape, polici, environ]                        5
# 10      [build, framework, intern, stabil, cyberspac]                        5
# 11  [depart, state, work, interag, partner, guid, ...                       43
# 12  [thi, framework, ha, three, key, element, glob...                       42
# 13  [sinc, unit, nation, group, government, expert...                       54
# 14  [applic, intern, law, first, fundament, pillar...                       87
# 15  [norm, respons, state, behavior, unit, state, ...                      104
# 16  [confid, build, measur, togeth, work, law, vol...                       82
# 17  [although, mani, element, framework, describ, ...                       65
# 18                                    [cyber, commit]                        2
# 19  [unit, state, strongli, oppos, use, cyber, tec...                       56
# 20  [govern, agre, cooper, provid, time, respons, ...                       15
# 21  [neither, countri, govern, conduct, knowingli,...                       11
# 22  [govern, work, togeth, identifi, promot, appro...                       18
# 23  [govern, establish, joint, dialogu, mechan, fi...                        9
# 24  [two, week, ago, today, may, unit, state, host...                       73
# 25  [implement, commit, reach, dure, presid, xi, v...                       59
# 26  [moreov, regard, commit, neither, govern, cond...                       33
# 27  [outcom, last, year, summit, focu, concret, ac...                       33
# 28                   [group, twenti, antalya, summit]                        4
# 29  [novemb, leader, met, antalya, turkey, discuss...                       29
# ..                                                ...                      ...
# 41  [russia, ha, nonetheless, found, common, groun...                       48
# 42  [counter, altern, concept, cyberspac, polici, ...                       32
# 43                   [respond, prevent, cyber, incid]                        4
# 44                           [continu, cyber, threat]                        3
# 45  [cyber, threat, nation, econom, secur, increas...                       51
# 46  [overal, unclassifi, inform, commun, technolog...                       69
# 47  [februari, director, nation, intellig, jame, c...                       56
# 48  [intellig, commun, continu, wit, increas, scal...                       37
# 49              [tool, avail, counter, cyber, threat]                        5
# 50  [unit, state, work, counter, technic, challeng...                       27
# 51  [unit, state, believ, deterr, cyberspac, best,...                       57
# 52  [presid, ha, hi, dispos, number, tool, carri, ...                       33
# 53  [respect, cost, imposit, presid, abl, draw, ra...                       13
# 54  [diplomat, tool, provid, way, commun, adversar...                       61
# 55  [law, enforc, tool, use, investig, crime, pros...                       46
# 56  [econom, tool, financi, sanction, may, use, pa...                       97
# 57  [militari, capabl, provid, import, set, option...                       72
# 58  [intellig, capabl, also, import, tool, presid,...                       24
# 59  [even, thi, broad, rang, tool, deter, cyber, t...                       26
# 60                                     [capac, build]                        2
# 61  [addit, tool, outlin, abil, unit, state, respo...                       60
# 62  [exampl, unit, state, join, netherland, found,...                       90
# 63  [anoth, exampl, capac, build, depart, state, b...                       76
# 64  [depart, state, commit, continu, capac, build,...                       18
# 65                                      [look, ahead]                        2
# 66  [cybersecur, continu, challeng, unit, state, t...                       50
# 67  [depart, continu, spearhead, effort, promot, i...                       36
# 68  [depart, state, remain, appreci, thi, subcommi...                       15
# 69                                                 []                        0
# 70  [offic, websit, manag, bureau, public, affair,...                       36
#
# [71 rows x 4 columns]

# %%
doscfdist = nltk.ConditionalFreqDist(((len(w), w) for w in DOS052516PD['normalized_tokens'].sum()))

#print the number of words
print(doscfdist.N())
# Out:
# 2867

# %%
doscfdist[3].plot()

# %%
porter = nltk.stem.porter.PorterStemmer()
print (porter.stem('this'))
# Out:
# thi

# %%
print (snowball.stem('this'))

DOS052516PD['normalized_tokens'] = DOS052516PD['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = snowball))
DOS052516PD['normalized_tokens_count'] = DOS052516PD['normalized_tokens'].apply(lambda x: len(x))
doscfdist = nltk.ConditionalFreqDist(((len(w), w) for w in DOS052516PD['normalized_tokens'].sum()))
doscfdist[3].plot()
# Out:
# this

# %%
doscpdist = nltk.ConditionalProbDist(doscfdist, nltk.ELEProbDist)

#print the most common 2 letter word
print(doscpdist[2].max())

#And its probability
print(doscpdist[2].prob(doscpdist[2].max()))
# Out:
# un
# 0.6

# %%
DOS052516PD['normalized_tokens_POS'] = [nltk.pos_tag(t) for t in DOS052516PD['normalized_tokens']]

# %%
doscfdist_WordtoPOS = nltk.ConditionalFreqDist(DOS052516PD['normalized_tokens_POS'].sum())
list(doscfdist_WordtoPOS.items())[:10]
# Out:
# [('view', FreqDist({'NN': 11, 'VBP': 2})),
#  ('inform', FreqDist({'JJ': 2, 'NN': 13})),
#  ('releas', FreqDist({'NNS': 1})),
#  ('onlin', FreqDist({'NN': 1, 'VBP': 2})),
#  ('januari', FreqDist({'JJ': 1, 'NN': 2})),
#  ('note', FreqDist({'NN': 5, 'VBP': 1})),
#  ('content', FreqDist({'NN': 3})),
#  ('archiv', FreqDist({'IN': 1})),
#  ('site', FreqDist({'NN': 4})),
#  ('updat', FreqDist({'JJ': 3}))]

# %%
doscfdist_WordtoPOS['cyber'].plot()

# %%
wc = wordcloud.WordCloud(background_color="white", max_words=500, width= 1000, height = 1000, mode ='RGBA', scale=.5).generate(' '.join(DOS052516PD['normalized_tokens'].sum()))
plt.imshow(wc)
plt.axis("off")
plt.savefig("DOS052516_word_cloud.pdf", format = 'pdf')

# %% [markdown]
# ANALYSIS FOR SPEECH JULY 29, 2015

# %%
DOS072915_url = 'https://2009-2017.state.gov/s/cyberissues/releasesandremarks/245720.htm'
DOS072915_save = 'DOS072915_url.html'
DOS072915 = requests.get(DOS072915_url)
DOS072915Soup = bs4.BeautifulSoup(DOS072915.text, 'html.parser')
with open(DOS072915_save, mode='w', encoding='utf-8') as f:
    f.write(DOS072915.text)
DOS072915PTags = DOS072915Soup.body.findAll('p')
DOS072915P = []
for pTag in DOS072915PTags:
    DOS072915P.append(pTag.text)
with open('DOS072915.txt', encoding = 'utf-8') as f:
    DOS072915 = f.read()
    
DOS072915Tokens = nltk.word_tokenize(DOS072915)

DOS072915Text = nltk.Text(DOS072915Tokens)

DOS072915Index = nltk.text.ConcordanceIndex(DOS072915Text)
DOS072915Index.print_concordance('cyber')
# Out:
# Displaying 25 of 30 matches:
# cb3 Since our last ARF workshop on cyber issues , in Malaysia last year , w
# have seen an increasing variety of cyber threats and incidents . We have al
# ess the U.S. perspective on recent cyber incidents and trends.\cb1 \ \pard\
# tate actors that conduct malicious cyber activity for unacceptable ends , i
#  infrastructure . North Korea\'92s cyber attack on Sony Pictures Entertainm
# lights a new and worrying trend of cyber capabilities being used from abroa
# ng series of low-to-moderate level cyber attacks from a variety of sources\
#  \cb3 Role of states/International cyber stability/norms \b0 \cb1 \ \pard\p
# amework of strategic international cyber stability : a more peaceful enviro
# nt and implementation of practical cyber confidence building measures.\cb1
# e requests in mitigating malicious cyber activity emanating from their terr
# ek to prevent the proliferation of cyber tools that can be used for malicio
# nfactor0 \b \cf2 \cb3 CBMs and ARF cyber work \b0 \cb1 \ \pard\pardeftab720
# In addition to our work on norms , cyber CBMs have the potential to contrib
# ute substantially to international cyber stability . CBMs have been used fo
# lay in the development of regional cyber CBMs \'96 a critical component of
# of this framework of international cyber stability.\cb1 \ \cb3 We are satis
# ers in the development of regional cyber confidence building measures to re
#  communication about transnational cyber incidents seems ripe for productiv
# partightenfactor0 \b \cf2 \cb3 ARF cyber work and cyber capacity building \
# r0 \b \cf2 \cb3 ARF cyber work and cyber capacity building \b0 \cb1 \ \pard
#  This workshop today is focused on cyber capacity building , which is an in
# have the capacity to implement the cyber CBMs we are hoping to develop . Be
# re , we should support the area of cyber capacity building linked directly
# ons General Assembly put forward a cyber self-assessment tool in UNGA resol

# %%
DOS072915PD = pandas.DataFrame({'paragraph-text' : DOS072915P})
def wordCounter(wordLst):
    wordCounts = {}
    for word in wordLst:
        wLower = word.lower()
        if wLower in wordCounts:
            wordCounts[wLower] += 1
        else:
            wordCounts[wLower] = 1
    countsForFrame = {'word' : [], 'count' : []}
    for w, c in wordCounts.items():
        countsForFrame['word'].append(w)
        countsForFrame['count'].append(c)
    return pandas.DataFrame(countsForFrame)

countedWords = wordCounter(DOS072915Text)

words = [word.lower() for word in DOS072915Text]
freq = nltk.FreqDist(words)
print (freq['cyber'])
# Out:
# 31

# %%
countedWords.sort_values('count', ascending=False, inplace=True)
countedWords[:200]
# Out:
#      count                                  word
# 35      85                                   the
# 40      72                                    of
# 37      65                                    to
# 42      58                                   and
# 53      58                                     ,
# 65      39                                     .
# 54      37                                    in
# 16      33                                     \
# 51      31                                 cyber
# 30      28                                  \cb3
# 57      28                                    we
# 50      27                                    on
# 143     26                                     a
# 34      23                                   for
# 5       20                                     }
# 0       20                                     {
# 95      19                                  that
# 160     18                                  this
# 70      18                         international
# 4       17                                     ;
# 164     16                                   are
# 234     16                                states
# 48      14                                   arf
# 277     13                                  work
# 29      12                                  \cf2
# 27      12  \pard\pardeftab720\partightenfactor0
# 41      12                            cyberspace
# 112     11                                  with
# 88      11                                   all
# 46      10                                   our
# ..     ...                                   ...
# 108      2                            commercial
# 73       2                               address
# 157      2                               another
# 104      2                               secrets
# 96       2                               conduct
# 94       2                                actors
# 167      2                             networked
# 371      2                         applicability
# 660      2                                effort
# 494      2                            unintended
# 429      2                         substantially
# 572      2                             implement
# 419      2                                  norm
# 428      2                            contribute
# 205      2                            particular
# 204      2                                   any
# 582      2                                   out
# 200      2                              recently
# 542      2                                 clear
# 561      2                                agenda
# 564      2                                   set
# 558      2                            discussion
# 239      2                             community
# 546      2                                    us
# 241      2                             addressed
# 243      2                                venues
# 244      2                             technical
# 553      2                                policy
# 235      2                                   but
# 403      2                               several
#
# [200 rows x 2 columns]

# %%
print(countedWords[countedWords['word'] == 'cyberspace'])
DOS072915Index.print_concordance('cyberspace')
# Out:
#     count        word
# 41     12  cyberspace
# Displaying 12 of 12 matches:
# nity to discuss developments of cyberspace and emerging challenges.\cb1 \
# obal , interconnected nature of cyberspace , these threats and potential c
# itively exploit the benefits of cyberspace and where there are benefits to
# f responsible state behavior in cyberspace and the development and impleme
# tional law to state behavior in cyberspace . The 2013 UN GGE report was a
# N charter , to state conduct in cyberspace . The recently concluded 2014-2
# f responsible state behavior in cyberspace . The 2015 report\'92s most sig
# aw applies to State behavior in cyberspace wherever possible , engaging al
# This is a problem that predates cyberspace but has become much more acute
# e . Otherwise , any activity in cyberspace could cause unintended reaction
#  community\'92s ability to keep cyberspace open , interoperable , secure a
# rnational peace and security in cyberspace . The ARF plays a critical role

# %%
DOS072915Text.collocations()
# Out:
# \cf2 \cb3; \listtext \uc0\u8226; \ls1\ilvl0\cb3
# \kerning1\expnd0\expndtw0; \b0 \cb1;
# \pard\pardeftab720\partightenfactor0 \cf2; Work Plan; capacity
# building; member states; international law; contribute substantially;
# trade secrets; state behavior; reduce risk; United States; networked
# information; cyber CBMs; State behavior; responsible state; critical
# infrastructure; international community

# %%
DOS072915Text.common_contexts(['cyber'])
# Out:
# on_issues of_threats recent_incidents malicious_activity
# korea\'92s_attack of_capabilities level_attacks
# states/international_stability/norms international_stability
# practical_confidence of_tools arf_work ,_cbms regional_cbms
# international_stability.\cb1 regional_confidence
# transnational_incidents arf_confidence and_capacity on_capacity

# %%
sns.reset_orig()
DOS072915Text.dispersion_plot(['cyber', 'cyberspace','stability', 'norms','attack', 'international'])
sns.set()

# %%
DOS072915PD['tokenized_text'] = DOS072915PD['paragraph-text'].apply(lambda x: nltk.word_tokenize(x))

# %%
countsDict = {}
for word in DOS072915PD['tokenized_text'].sum():
    if word in countsDict:
        countsDict[word] += 1
    else:
        countsDict[word] = 1
word_counts = sorted(countsDict.items(), key = lambda x : x[1], reverse = True)
word_counts[:30]
# Out:
# [('the', 79),
#  ('of', 73),
#  ('to', 68),
#  (',', 64),
#  ('.', 63),
#  ('and', 54),
#  ('in', 33),
#  ('cyber', 29),
#  ('on', 25),
#  ('a', 24),
#  ('for', 19),
#  ('that', 19),
#  ('international', 18),
#  ('are', 17),
#  ('We', 16),
#  ('ARF', 15),
#  ('this', 14),
#  ('cyberspace', 12),
#  ('we', 12),
#  ('is', 10),
#  ('not', 10),
#  ('our', 10),
#  ('all', 10),
#  ('States', 10),
#  ('work', 10),
#  ('other', 9),
#  ('an', 9),
#  ('with', 9),
#  ('The', 9),
#  ('can', 9)]

# %%
stop_words_freq = []
for word, count in word_counts:
    if word == 'cyber':
        break
    else:
        stop_words_freq.append(word)
stop_words_freq
wordnet = nltk.stem.WordNetLemmatizer()
wordnet.lemmatize('are')
# Out:
# 'are'

# %%
stop_words_nltk = stopwords.words('english')
porter = nltk.stem.porter.PorterStemmer()
snowball = nltk.stem.snowball.SnowballStemmer('english')
wordnet = nltk.stem.WordNetLemmatizer()
def normlizeTokens(tokenLst, stopwordLst = None, stemmer = None, lemmer = None):
    #We can use a generator here as we just need to iterate over it

    #Lowering the case and removing non-words
    workingIter = (w.lower() for w in tokenLst if w.isalpha())

    #Now we can use the semmer, if provided
    if stemmer is not None:
        workingIter = (stemmer.stem(w) for w in workingIter)
        
    #And the lemmer
    if lemmer is not None:
        workingIter = (lemmer.lemmatize(w) for w in workingIter)
    
    #And remove the stopwords
    if stopwordLst is not None:
        workingIter = (w for w in workingIter if w not in stopwordLst)
    #We will return a list with the stopwords removed
    return list(workingIter)

DOS072915PD['normal_tokens'] = DOS072915PD['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = porter))
DOS072915PD['normal_tokens_count'] = DOS072915PD['normal_tokens'].apply(lambda x: len(x))

DOS072915PD
# Out:
#                                        paragraph-text  \
# 0                                    You are viewing:
# 1   Information released online from January 20, 2...
# 2
# 3   Thank you for the opportunity to discuss devel...
# 4   Since our last ARF workshop on cyber issues, i...
# 5   First, I’d like to briefly address the U.S. pe...
# 6                                Incidents and trends
# 7   We all face increasing risks from state and no...
# 8   We are all increasingly dependent on networked...
# 9   As the U.S. Director of National Intelligence ...
# 10  These issues are being addressed in a wide var...
# 11  Role of states/International cyber stability/n...
# 12  As one of these stewards, States must recogniz...
# 13  In this regard, the United States believes tha...
# 14  There are two pillars to our approach: the dev...
# 15  We continue to make great strides in deepening...
# 16  We also made important progress in building co...
# 17  These efforts do not conclude with this GGE ro...
# 18                            CBMs and ARF cyber work
# 19  In addition to our work on norms, cyber CBMs h...
# 20  Given the ARF’s objective to “make significant...
# 21  We are satisfied with the consensus that has b...
# 22  We are prepared to continue working with willi...
# 23         ARF cyber work and cyber capacity building
# 24  This workshop today is focused on cyber capaci...
# 25  Several years ago, the United Nations General ...
# 26  As we look to implementing ARF regional cyber ...
# 27  The need for capacity building and exchange of...
# 28                                         Conclusion
# 29  Thanks again for the opportunity to speak toda...
# 30
# 31  \nThe Office of Website Management, Bureau of ...
#
#                                        tokenized_text  \
# 0                              [You, are, viewing, :]
# 1   [Information, released, online, from, January,...
# 2                                                  []
# 3   [Thank, you, for, the, opportunity, to, discus...
# 4   [Since, our, last, ARF, workshop, on, cyber, i...
# 5   [First, ,, I, ’, d, like, to, briefly, address...
# 6                            [Incidents, and, trends]
# 7   [We, all, face, increasing, risks, from, state...
# 8   [We, are, all, increasingly, dependent, on, ne...
# 9   [As, the, U.S., Director, of, National, Intell...
# 10  [These, issues, are, being, addressed, in, a, ...
# 11  [Role, of, states/International, cyber, stabil...
# 12  [As, one, of, these, stewards, ,, States, must...
# 13  [In, this, regard, ,, the, United, States, bel...
# 14  [There, are, two, pillars, to, our, approach, ...
# 15  [We, continue, to, make, great, strides, in, d...
# 16  [We, also, made, important, progress, in, buil...
# 17  [These, efforts, do, not, conclude, with, this...
# 18                      [CBMs, and, ARF, cyber, work]
# 19  [In, addition, to, our, work, on, norms, ,, cy...
# 20  [Given, the, ARF, ’, s, objective, to, “, make...
# 21  [We, are, satisfied, with, the, consensus, tha...
# 22  [We, are, prepared, to, continue, working, wit...
# 23  [ARF, cyber, work, and, cyber, capacity, build...
# 24  [This, workshop, today, is, focused, on, cyber...
# 25  [Several, years, ago, ,, the, United, Nations,...
# 26  [As, we, look, to, implementing, ARF, regional...
# 27  [The, need, for, capacity, building, and, exch...
# 28                                       [Conclusion]
# 29  [Thanks, again, for, the, opportunity, to, spe...
# 30                                                 []
# 31  [The, Office, of, Website, Management, ,, Bure...
#
#                                         normal_tokens  normal_tokens_count
# 0                                              [view]                    1
# 1   [inform, releas, onlin, januari, januari, note...                   24
# 2                                                  []                    0
# 3   [thank, opportun, discuss, develop, cyberspac,...                    7
# 4   [sinc, last, arf, workshop, cyber, issu, malay...                   24
# 5   [first, like, briefli, address, perspect, rece...                    9
# 6                                      [incid, trend]                    2
# 7   [face, increas, risk, state, actor, conduct, m...                   69
# 8   [increasingli, depend, network, inform, system...                   36
# 9   [director, nation, intellig, recent, note, lik...                   45
# 10  [issu, address, wide, varieti, venu, includ, t...                   58
# 11                                      [role, cyber]                    2
# 12  [one, steward, state, must, recogn, role, focu...                   33
# 13  [thi, regard, unit, state, believ, intern, com...                   34
# 14  [two, pillar, approach, develop, intern, conse...                   19
# 15  [continu, make, great, stride, deepen, common,...                   61
# 16  [also, made, import, progress, build, consensu...                   70
# 17  [effort, conclud, thi, gge, round, continu, pr...                   69
# 18                            [cbm, arf, cyber, work]                    4
# 19  [addit, work, norm, cyber, cbm, potenti, contr...                   61
# 20  [given, arf, object, make, signific, contribut...                   29
# 21  [satisfi, consensu, ha, reach, follow, mani, m...                   42
# 22  [prepar, continu, work, arf, partner, develop,...                   69
# 23            [arf, cyber, work, cyber, capac, build]                    6
# 24  [thi, workshop, today, focus, cyber, capac, bu...                   58
# 25  [sever, year, ago, unit, nation, gener, assemb...                   24
# 26  [look, implement, arf, region, cyber, cbm, arf...                   17
# 27  [need, capac, build, exchang, expertis, cyber,...                   28
# 28                                          [conclus]                    1
# 29  [thank, opportun, speak, today, explain, work,...                   21
# 30                                                 []                    0
# 31  [offic, websit, manag, bureau, public, affair,...                   36

# %%
dos2cfdist = nltk.ConditionalFreqDist(((len(w), w) for w in DOS072915PD['normal_tokens'].sum()))

#print the number of words
print(dos2cfdist.N())
# Out:
# 959

# %%
porter = nltk.stem.porter.PorterStemmer()
print (snowball.stem('this'))

DOS072915PD['normal_tokens'] = DOS072915PD['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = snowball))
DOS072915PD['normal_tokens_count'] = DOS072915PD['normal_tokens'].apply(lambda x: len(x))
dos2cfdist = nltk.ConditionalFreqDist(((len(w), w) for w in DOS072915PD['normal_tokens'].sum()))
dos2cfdist[3].plot()
# Out:
# this

# %%
dos2cpdist = nltk.ConditionalProbDist(dos2cfdist, nltk.ELEProbDist)

#print the most common 2 letter word
print(dos2cpdist[2].max())

#And its probability
print(dos2cpdist[2].prob(dos2cpdist[2].max()))
# Out:
# un
# 0.5

# %%
DOS072915PD['normal_tokens_POS'] = [nltk.pos_tag(t) for t in DOS072915PD['normal_tokens']]

# %%
dos2cfdist_WordtoPOS = nltk.ConditionalFreqDist(DOS072915PD['normal_tokens_POS'].sum())
list(dos2cfdist_WordtoPOS.items())[:10]
# Out:
# [('view', FreqDist({'NN': 3, 'VBP': 2})),
#  ('inform', FreqDist({'JJ': 1, 'NN': 6})),
#  ('releas', FreqDist({'NNS': 1})),
#  ('onlin', FreqDist({'VBP': 1})),
#  ('januari', FreqDist({'JJ': 1, 'NN': 1})),
#  ('note', FreqDist({'NN': 3})),
#  ('content', FreqDist({'NN': 1})),
#  ('archiv', FreqDist({'IN': 1})),
#  ('site', FreqDist({'NN': 4})),
#  ('updat', FreqDist({'JJ': 1}))]

# %%
dos2cfdist_WordtoPOS['cyber'].plot()

# %%
wc2 = wordcloud.WordCloud(background_color="white", max_words=500, width= 1000, height = 1000, mode ='RGBA', scale=.5).generate(' '.join(DOS072915PD['normal_tokens'].sum()))
plt.imshow(wc)
plt.axis("off")
plt.savefig("DOS072915_word_cloud.pdf", format = 'pdf')
